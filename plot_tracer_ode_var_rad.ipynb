# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import sys
sys.path.append("/richmondvol1/rusty/stompy")
from stompy import utils
import stompy.model.delft.dflow_model as dfm
import stompy.model.delft.waq_scenario as dwaq
from stompy.plot import plot_utils
from stompy.grid import unstructured_grid
from matplotlib import colors
import pandas as pd
import os
import numpy as np
import xarray as xr
import subprocess
from scipy.integrate import odeint
from numba import njit

from IPython.display import Video
import time
import six
import datetime
import glob
from stompy.plot import nbviz

# %%
# run_wy2022_bloom_common_20220810:
#   dye1, oakland release, non-temp hydro
# run_wy2022_bloom_common_20220810-v001
#   oakland, eastshore releases. temp hydro.
# run_wy2022_bloom_common_20220810-v002
#   oakland release, temp hydro, 16.62 integration
# run_wy2022_bloom_common_20220810-v003"
#   oakland release in top 2m of water column
# run_wy2022_bloom_common_20220515-v002
#   testing custom tracer
# run_wy2022_bloom_common_20220810-v007
#   age and depth tracers
# run_wy2022_bloom_common_20220810-v007
#   age and depth tracers for continuous release.
# run_wy2022_bloom_common_20220705
#   age and depth tracers for continuous release, longer period w/ EBDA
#   EBDA exposure misconfigured
# run_wy2022_bloom_common_20220705-v001
#   fix EBDA exposure
# run_wy2022_bloom_common_20220705-v003
#   LSB exposure, age variance, 0.1/day decay of EBDA and LSB
#   has variance, but it's broken.
# run_wy2022_bloom_common_20220705-v004
#   Should have variance fixed now
# run_wy2022_bloom_common_20220705-v005
#   Conservative/decaying tracers for EBDA and LSB 
# run_wy2022_bloom_common_20220802
#   Start at the time of release, and drop the extra POTW tracers
# run_wy2022_bloom_common_20220805-v007
#   Add light exposure, short run for testing. 
# run_wy2022_bloom_common_20220802-v001
#   With light exposure, longer run. But light exposure seems to be broken.
# run_wy2022_bloom_common_20220802-v001
#   Use RadBot instead of Rad
# run_wy2022_bloom_common_20220802-v003
#   hourly Kd and hourly SolRad
run_dir="run_wy2022_bloom_common_20220802-v003"

# %%
ds=xr.open_dataset(os.path.join(run_dir,"dwaq_map.nc"))

# %%
grid=unstructured_grid.UnstructuredGrid.read_ugrid(ds)
from stompy.plot import plot_wkb
grid_poly=grid.boundary_polygon()
# Out:
# INFO:join_features:0 open strings, 16 simple polygons
# INFO:join_features:Building index
# /richmondvol1/rusty/stompy/stompy/spatial/join_features.py:514: ShapelyDeprecationWarning: Setting custom attributes on geometry objects is deprecated, and will raise an AttributeError in Shapely 2.0
#   p.join_id=i
# INFO:join_features:done building index
# INFO:join_features:Examining largest poly left with area=3212664407.249210, 15 potential interiors

# %%
def ratio(a,b,b_min=1e-8):
    return a/b.clip(b_min) * np.where(b<b_min,np.nan, 1.0)

# %%
six.moves.reload_module(nbviz)
# dev: eventually automate more of this.
def safe_ratio(numer,denom,thresh=1e-5):
    def func(src,dims):
        thresh=1e-5
        v_numer=src(numer,dims)
        v_denom=src(denom,dims)
        return v_numer / v_denom.clip(thresh)
    return func

def radio_age(cons,decay,rate=0.10):
    fratio=safe_ratio(decay,cons)
    def func(src,dims):
        rat = fratio(src,dims)
        return np.log(rat)/np.log(1-rate)
    return func

def stddev(conc,age_conc,var_conc):
    f_age=safe_ratio(age_conc,conc)
    f_mom2=safe_ratio(var_conc,conc)
    
    def func(src,dims,f_age=f_age,f_mom2=f_mom2):
        age=f_age(src,dims)
        mom2=f_mom2(src,dims)
        # mostly sure of the factor of 2 here.
        return np.sqrt( mom2-age*age/2 )
    return func

viz=nbviz.NBViz(
    [ds],
    expressions=[
      nbviz.BoundExpression(name='age',dims=['time','layer','face'],func=safe_ratio('Age1AConc','Age1Conc')),
      nbviz.BoundExpression(name='avg_depth',dims=['time','layer','face'],func=safe_ratio('Age1DAConc','Age1AConc')),
      nbviz.BoundExpression(name='avg_rad',dims=['time','layer','face'],func=safe_ratio('Age1RadAge','Age1AConc')),
      #nbviz.BoundExpression(name='avg_ebda',dims=['time','layer','face'],func=safe_ratio('Age1NAConc','Age1AConc')),
      #nbviz.BoundExpression(name='expo_ebda',dims=['time','layer','face'],func=safe_ratio('Age1NAConc','Age1Conc')),
      #nbviz.BoundExpression(name='avg_lsb',dims=['time','layer','face'],func=safe_ratio('Age1LAConc','Age1AConc')),
      #nbviz.BoundExpression(name='expo_lsb',dims=['time','layer','face'],func=safe_ratio('Age1LAConc','Age1Conc')),
      #nbviz.BoundExpression(name="age_lsb",dims=['time','layer','face'],func=radio_age('LSBcon','LSB')),
      #nbviz.BoundExpression(name="age_ebda",dims=['time','layer','face'],func=radio_age('EBDAcon','EBDA')),
        
      nbviz.BoundExpression(name='age_stddev',dims=['time','layer','face'],
                            func=stddev('Age1Conc','Age1AConc','Age1VConc')),
    ])
                

viz
# Out:
# <img src="data:image/png;base64,..." width="924.5454345064719">
# Checking for edge vars
# edge dimension: edge
# NBViz(children=(VBox(children=(Label(value='Coordinates'),), layout=Layout(grid_area='header')), Select(descri…

# %%
# Diagnosing rad tracer
pnts= [[552100,4.1881e6], # CB
       [560200,4.1739e6], # Hunters point
       [564500,4.133e6], # SFO
]
pnt_labels=['CB','Hunter','SFO']


fig,(ax,ax_d,ax2)=plt.subplots(3,1,sharex=True,figsize=[8.5,7])

#ax_d = ax.twinx()

for pnt,pnt_label in zip(pnts,pnt_labels):
    c=grid.select_cells_nearest(pnt)

    for k in [1]:
        #tag=f'(k={k},x={pnt_label})'
        tag=f'(x={pnt_label})'
        
        age_conc=ds['Age1AConc'].isel(layer=k,face=c)

        #ax.plot(ds.time, ds.Rad.isel(layer=k,face=c),label=f'Rad(k={k})')
        rad_age=ds['Age1RadAge'].isel(layer=k,face=c)
        #ax.plot(ds.time, rad_age,label=f'RadAge(k={k})')
        ax.plot(ds.time, rad_age/age_conc,label=f'avg_rad{tag}')
        #ax.plot(ds.time, rad_age/age_conc.clip(1e-5),label='avg_rad safe')

        depth_age=ds['Age1DAConc'].isel(layer=k,face=c)
        #ax_d.plot(ds.time, ds.LocalDepth.isel(layer=k,face=c),label=f'LocDepth(k={k})')
        #ax.plot(ds.time, depth_age,label=f'DepthAge(k={k})')
        d_avg= depth_age / age_conc
        ax_d.plot(ds.time, d_avg,label=f'avg_depth{tag}')

        # highly inaccurate, but maybe shows relationship:
        # average of an exponential isn't the same as exponential of the average,
        # but throw in a fudge factor and it's close.
        #I0=500
        #Kd=2.0
        #ax.plot( ds.time, I0*np.exp(-0.33*Kd*d_avg), label='$\sim I_0 e^{-Kd \overline{h}}$',color='r' )

        #ax2.plot(ds.time, age_conc,label=f'AgeConc{tag}')
        #conc=ds['Age1Conc'].isel(layer=k,face=c)
        #ax2.plot(ds.time, conc,label='conc')
        #ax2.plot(ds.time, age_conc/conc,label='age')
        #ax2.plot(ds.time, (ds.time-ds.time.values[0])/np.timedelta64(1,'D'),label='max age')
    
        kd=ds['ExtVl'].isel(layer=k,face=c)
        ax2.plot(ds.time, kd,label=f'ExtVl{tag}')
        
fig.subplots_adjust(right=0.76,left=0.05,top=0.99,bottom=0.08,hspace=0.06)    

ax.legend(loc='upper left',bbox_to_anchor=[1.01,1])
ax2.legend(loc='upper left', bbox_to_anchor=[1.01,1])
ax_d.legend(loc='upper left', bbox_to_anchor=[1.01,1])

ax_d.axis(ymin=0,ymax=12)
ax.axis(ymin=0,ymax=60)
# Out:
# <img src="data:image/png;base64,..." width="850">
# (19204.952083333334, 19228.00625, 0.0, 60.0)

# %%
frac=0.1
M=grid.smooth_matrix()

# %%
def fill(values,iterations=50):
    valid=np.isfinite(values)
    data=np.where(valid,values,0.0)
    weight=np.where(valid,1,0.0)
    for _ in range(iterations):
        data=M.dot(data)
        weight=M.dot(weight)
        data[valid]=values[valid]
        weight[valid]=1.0
    result=np.full(len(values),np.nan)
    valid=weight>1e-4
    result[valid]=data[valid]/weight[valid]
    return result

# %%
# Choose a time and show the tracer outputs
t=np.datetime64("2022-08-16")
layer=0

zoom=(534866.147091273, 587089.832126076, 4151509.9875591, 4202696.11593758)

age_conc=ds['Age1AConc'].sel(time=t,method='nearest').isel(layer=0)
conc    =ds['Age1Conc'].sel(time=t,method='nearest').isel(layer=0)
age_depth_conc=ds['Age1DAConc'].sel(time=t,method='nearest').isel(layer=0)

max_age=(t-ds.time.values[0])/np.timedelta64(1,'D')
mean_age=ratio(age_conc,conc).clip(0,max_age)

mean_depth=ratio(age_depth_conc, age_conc)
valid=conc.values>=0.008 # covers to just N of DMB, and into Central Bay
H=mean_depth.values

var_conc=ds['Age1VConc'].sel(time=t,method='nearest').isel(layer=0)

scals=[mean_depth,np.log10(conc.clip(1e-2)),
       mean_age,
       #(mean_age**2/2).clip(0,500)
      ]
labels=['Mean depth (m)','log$_{10}$(Conc)','Mean age (d)']

#scals.append(var_conc)
#labels.append('Var.-conc')

#scals.append(ratio(var_conc,conc).clip(0,500))
#labels.append('2nd mom')

scals.append( np.sqrt( (ratio(var_conc,conc) - mean_age**2/2)).clip(0,10))
labels.append('age-std?')


fig,axs=plt.subplots(2,2,figsize=(8.5,7.5))

plt.setp(axs, adjustable='datalim')
for ax in axs.ravel():
    ax.axis('off')
fig.tight_layout()
for i,(ax,scal,label) in enumerate(zip(axs.ravel(),scals,labels)):
    grid.plot_cells(color='0.8',zorder=0,ax=ax)
    ccoll=grid.plot_cells(values=scal,mask=np.isfinite(scal),ax=ax,cmap='turbo',zorder=1,
                          edgecolor='face',lw=0.3)
    ax.axis(zoom)
    plt.colorbar(ccoll,ax=ax)

    ax.text(0.5,0.8,label,transform=ax.transAxes,fontsize=13)
# Out:
# /home/rusty/.conda/envs/general_rh/lib/python3.9/site-packages/xarray/core/computation.py:727: RuntimeWarning: invalid value encountered in sqrt
#   result_data = func(*input_data)
# <img src="data:image/png;base64,..." width="849.9999815767466">

# %%
class Petri:

    # From Pradeep:
    kprod=1.6 # value for Greens
    kmort=0.15 # BGC uses 0.07 for Greens, but doesn't include grazing.
    #    mgN/l:mgC/l    μM N : mgN/l   mgC/l : μg/l Chl (lit. value)
    alpha=0.16         * 71.1        * 30/1000. # ~ 0.34
    Nsat=1.0 # in the middle of Pradeep's 0.7 -- 2 range of lit. values
    Isat=17 # Greens. [W/m2]
    I0=175 # PM: 700-800 peak at Union City. 350-400 daily mean. 175-200 PAR
    Kd=1.0

    def __init__(self,**kw):
        utils.set_keywords(self,kw)
        
    def diff(state,t,Hmean):
        P,N=state
        N=N.clip(0) # no evidence this is really necessary
        P=P.clip(0) # likewise.
        Imean=self.I0*np.exp(-self.Kd*Hmean)
        kLight=Imean/(Imean+self.Isat)
        # duplicate while testing.
        kDIN=N/(N+self.Nsat)
        dgrossP = self.kprod*kLight*kDIN*P
        dnetP = -self.kmort*P + dgrossP
        dN = -self.alpha*dgrossP
        return np.r_[dnetP,dN]

    # t: days
    # c0: phytoplankton as chl ug/l
    # Hmean: meters
    def predict(self, c0, age, Hmean,N0=None, Imean=None):
        if N0 is None:
            N0=self.N0

        if Imean is None:
            Imean=self.I0*np.exp(-self.Kd*Hmean)
            
        kLight=Imean/(Imean+self.Isat)

        age=np.atleast_1d(age)
        if len(age)==1:
            t_vals=np.r_[0,age[0]] # linspace(0,15,200)
        else:
            t_vals=age
            
        params=np.array([self.Nsat,self.kprod*kLight,self.kmort,self.alpha])
        result=odeint(self.nb_diff,[c0,N0],t_vals,tfirst=True,
                      args=(params,))
        
        if len(age)==1:
            return result[-1,:]
        else:
            return result

    @staticmethod
    @njit
    def nb_diff(t,state,params):
        P=max(0,state[0]) # .clip(0)
        N=max(0,state[1]) # .clip(0)
        Nsat=params[0]
        k_prod_light=params[1]
        k_mort=params[2]
        alpha=params[3]
        
        kDIN=N/(N+params[0])
        dgrossP = k_prod_light*kDIN*P
        dnetP = -k_mort*P + dgrossP
        dN = -alpha*dgrossP
        return np.array([dnetP,dN])
        
    def predict_many(self,c0,age,Hmean,N0=None,Imean=None):
        if N0 is None:
            N0=self.N0
        N0=np.atleast_1d(N0)
        
        if Imean is None:
            Imean=self.I0*np.exp(-self.Kd*Hmean)
                    
        t_start=time.time()
        B=np.broadcast(c0,age,Hmean,N0,Imean)
        result=np.zeros(B.shape+(2,),np.float64)
        resultR=result.reshape([-1,2])
        for c0,age,Hmean,N0,I in B:
            resultR[B.index-1,:]=self.predict(c0,age,Hmean,N0,I)
        elapsed=time.time()-t_start
        print(f"Elapsed time for {B.size} samples: {elapsed:.3f}s")
        return result

# %%
zoom=(534866.147091273, 587089.832126076, 4151509.9875591, 4202696.11593758)

# %%
mapping_df=pd.read_csv('../Kd_2022/mapping/summer2022_condensed.csv',
                       parse_dates=['Datetime']).rename({'Datetime':'time'},axis=1)
# time, utm_x, utm_y, chla_avg, NO3.mgL

# %%
mapping_df.time.values[80000]
# Out:
# numpy.datetime64('2022-08-17T11:26:00.000000000')

# %%
# interesting region for the polygon release:
# source_strength=100 # tracer release is unit concentration. scale up to get source ug/l
# petri_args=dict(Kd=0.4)
from stompy import utils
from scipy import stats # norm

class LiveBloom:
    # dynamic inputs
    source_strength=0.1 # tracer release is unit concentration. scale up to get source ug/l

    c_thresh=0.000
    t=np.datetime64("2022-08-16")
    layer=0
    # post-hoc timing of release
    release_start=np.datetime64("2022-08-02")
    release_sigma_days='auto' # 3
    frac=0.05
    
    # ebda, lsb discharges go into DWAQ at 10000 [g/s]
    # ebda, 2013 average load was 7870 kg/d
    ebda_load=7870 # kg/d, just EBDA.
    lsb_load=2350 + 890 + 4800 # Palo Alto, Sunnyvale, San Jose
    ebda_factor=0.0
    lsb_factor=0.0
    N0=35
    
    # plotting controls
    figsize=(9,7)
    panels=[['Chl-a','DIN','log10(C0)'],
            ['effective_age','mean_depth','mean_rad']]
    
    # constant-ish
    zoom=(534866.147091273, 587089.832126076, 4151509.9875591, 4202696.11593758)
    background=False

    clims={'Chl-a':[0,120],
           'DIN':[0,35],
           'log10(C0)':[-3,2],
           'effective_age':[0,20],
           'mean_depth':[0,10],
           'stddev_age':[0,10],
           'mean_rad':[0,100],
          }
           
    def __init__(self,ds,**kw):
        utils.set_keywords(self,kw)
        self.petri=Petri()
        self.ds=ds
        self.grid=unstructured_grid.UnstructuredGrid.read_ugrid(ds)
        
        # the cell fields to be plotted
        self.conc=np.zeros(self.grid.Ncells())
        self.mean_age=np.zeros(self.grid.Ncells())
        self.mean_depth=np.zeros(self.grid.Ncells())
        self.mean_rad=np.zeros(self.grid.Ncells())
        
        self.predicted=np.zeros( (self.grid.Ncells(),2),np.float64)

        self.chl=self.predicted[:,0]
        self.din=self.predicted[:,1]
        
    def run(self):
        ds=self.ds
        t=self.t # the time of the snapshot.
        
        age_conc=ds['Age1AConc'].sel(time=t,method='nearest').isel(layer=self.layer).values
        self.conc[:] = conc =ds['Age1Conc'].sel(time=t,method='nearest').isel(layer=self.layer).values
        age_depth_conc=ds['Age1DAConc'].sel(time=t,method='nearest').isel(layer=self.layer).values

        min_conc=1e-5
        max_age=(t-ds.time.values[0])/np.timedelta64(1,'D')
        self.mean_age[:]=ratio(age_conc,conc,b_min=min_conc).clip(0,max_age)
        self.mean_depth[:]=ratio(age_depth_conc, age_conc, b_min=min_conc)

        age_rad_conc=ds['Age1RadAge'].sel(time=t,method='nearest').isel(layer=self.layer).values
        self.mean_rad[:]=ratio(age_rad_conc, age_conc, b_min=min_conc)
        
        weight=1.0
        if self.release_start is not None:
            # t0 for parcel relative to release
            t_relative=(t-self.release_start)/np.timedelta64(1,'D') - self.mean_age
            # gaussian fall off. That might be too broad, though.
            if self.release_sigma_days=='auto':
                # really this is 2nd moment-concentration.
                var_conc=ds['Age1VConc'].sel(time=t,method='nearest').isel(layer=self.layer).values
                rel_sigma=((ratio(var_conc,conc)-self.mean_age**2/2).clip(0))**0.5
                self.std_age=rel_sigma
            else:
                rel_sigma=self.release_sigma_days
                self.std_age=None
            # pull from the cumulative distribution.
            # t_relative gives the time since the release
            # weight=stats.norm.cdf( t_relative, loc=0, scale=rel_sigma.clip(0.1))
            
            # rough cut: truncate t_relative
            # the refinement is to think about the normal distribution, we're integrating
            # the mass after the release, and I want the centroid of that chunk.
            # if there is a release_start, then we consider the age distribution as a normal
            # distribution with mean/stddev from the tracers.
            # some of the tracer mass is from before the release, and weight is adjusted to
            # reflect only the mass from after the release. An upper bound on the age is the
            # time since the release. 
            max_age=(t-self.release_start)/np.timedelta64(1,'D')
            if 0: # simpler approach
                effective_age=self.mean_age.clip(0,max_age) 
            else:
                # a more precise measure is to calculate the mean of the truncated distribution.
                # https://en.wikipedia.org/wiki/Truncated_normal_distribution
                # mu + (phi(alpha)-phi(beta))/Z*sigma
                # mu = self.mean_age, the original mean
                a=0 # lower bound on age
                b=max_age # b=upper bound on age, t-self.release_start
                mu=self.mean_age
                sigma=np.where( np.isnan(rel_sigma) | (rel_sigma<0.1), 0.1,rel_sigma)                
                alpha=(a-mu)/sigma
                beta=(b-mu)/sigma
                phi=stats.norm.pdf
                Phi=stats.norm.cdf
                Z=Phi(beta) - Phi(alpha)
                effective_age=mu + (phi(alpha) - phi(beta))*sigma/Z
                # can get some 0 weight entries that disapper 
                effective_age=np.where( np.isfinite(effective_age),effective_age,max_age)
                assert not np.any( np.isnan(effective_age) & np.isfinite(mu))
                assert np.nanmin(effective_age)>=0
                assert np.nanmax(effective_age)<=max_age
                weight=Z # should trim on both sides
        else:
            # effective age is the period over which the ODEs are integrated.
            # if there's no release_start, the de facto release_start is the start of the
            # simulation and the mean_age already reflects that.
            effective_age=self.mean_age

        N0=self.N0*np.ones_like(self.mean_age)
        if self.ebda_factor!=0.0:
            ebda_age_conc=ds['Age1NAConc'].sel(time=t,method='nearest').isel(layer=self.layer).values
            ebda_avg=ratio(ebda_age_conc,age_conc)
            # convert to DIN: ebda_avg is relative to source strength of 10kg/s
            # kg/d * d/s / waq_rate
            # ebda_avg: g/m3 based on 10kg/s load
            # g/m3 => uM    * (ebda load in kg/s) / (waq load of 10kg/s)
            waq_to_din=71.1 * (self.ebda_load / 86400.) / 10.
            N0+=ebda_avg*self.ebda_factor*waq_to_din
        if self.lsb_factor!=0.0:
            lsb_age_conc=ds['Age1LAConc'].sel(time=t,method='nearest').isel(layer=self.layer).values
            lsb_avg=ratio(lsb_age_conc,age_conc)
            # convert to DIN: lsb_avg is relative to source strength of 10kg/s
            # kg/d * d/s / waq_rate
            waq_to_din=71.1 * (self.lsb_load / 86400.) / 10.
            N0+=lsb_avg*self.lsb_factor*waq_to_din            
            
        c0=weight * self.source_strength * self.conc
        self.c0=c0

        valid=(c0>=self.c_thresh) & np.isfinite(self.mean_age)
        idxs=np.nonzero(valid)[0]
        # select a random subset of idxs to actually simulate
        idxs=idxs[np.random.random(len(idxs))<self.frac]

        self.effective_age=effective_age
        self.predicted[:,:] = np.nan
        self.predicted[idxs,:] = self.petri.predict_many(self.c0[idxs],#self.mean_age[idxs],
                                                         effective_age[idxs],
                                                         self.mean_depth[idxs],
                                                         N0=N0[idxs],
                                                         Imean=self.mean_rad[idxs])
        self.predicted[:,0]=fill(self.predicted[:,0])
        self.predicted[:,1]=fill(self.predicted[:,1])

    fig=None
    text=None
    def figure(self,update=True):
        if self.fig is None:
            update=False
            
        panels=np.array(self.panels)

        clip=utils.expand_xxyy(self.zoom,0.3)

        if not update:
            self.fig,self.axs=plt.subplots(panels.shape[0],panels.shape[1],figsize=self.figsize)
            plt.setp(self.axs, adjustable='datalim')

            for ax in self.axs.ravel():
                ax.axis('off')
                if self.background:
                    grid.plot_cells(color='0.8',zorder=0,ax=ax,clip=clip)
            self.fig.subplots_adjust(left=0.02,right=0.98,top=0.98,bottom=0.02,
                                     hspace=0.01,wspace=0.08)

        labels=panels.ravel()
        scals=[]
        scats=[] # scatter plots, as [N, {x,y,value}]
        for label in labels:
            scat=None
            if label=='Chl-a':
                scals.append(self.chl)
                t_buff=np.timedelta64(1,'D')
                sel=(mapping_df.time>self.t-t_buff) & (mapping_df.time<self.t+t_buff)
                scat=mapping_df[sel][ ['utm_x','utm_y','chla_avg'] ].values
            elif label=='DIN':
                scals.append(self.din)
            elif label=='log10(C0)':
                scals.append(np.log10(self.c0.clip(1e-5)))
            elif label=='mean_age':
                scals.append(self.mean_age)
            elif label=='effective_age':
                scals.append(self.effective_age)
            elif label=='mean_depth':
                scals.append(self.mean_depth)
            elif label=='mean_rad':
                scals.append(self.mean_rad)
            elif label=='stddev_age':
                scals.append(self.std_age.clip(0,0.4*np.nanmean(self.mean_age)))
            elif label is None:
                scals.append(None)
            else:
                raise Exception("Unknown panel %s"%label)
            scats.append(scat)
            
        # hack for instant-start
        valid=np.isfinite(self.din * self.c0)

        plots=list(zip(self.axs.ravel(),scals,labels,scats))
        t_str=str(self.t)[:16]        
        
        if not update:
            self.ccolls=[]
            self.scatcolls=[]
            ax_txt=self.axs.ravel()[0]
            self.text=ax_txt.text(0.5,0.83,t_str,transform=ax_txt.transAxes)
            
            for ax,scal,label,scat in plots:
                if scal is None: 
                    self.ccolls.append(None)
                else:
                    plot_wkb.plot_wkb(grid_poly,color='0.8',zorder=-1,ax=ax)
                    valid=np.isfinite(scal)
                    scal=np.where(valid,scal,0.0)

                    ccoll=grid.plot_cells(values=scal,clip=clip,
                                          mask=np.isfinite(scal),ax=ax,cmap='turbo',zorder=1,
                                          edgecolor='face',lw=0.3)
                    #plt.colorbar(ccoll,ax=ax)
                    plot_utils.cbar(ccoll,ax=ax)
                    self.ccolls.append(ccoll)
                    ax.text(0.5,0.75,label,transform=ax.transAxes)
                    ax.axis(zoom)
                if scat is None or len(scat)==0:
                    self.scatcolls.append(None)
                else:
                    sc=ax.scatter(scat[:,0], scat[:,1], 20, scat[:,2],cmap='turbo',
                                  zorder=2)
                    self.scatcolls.append(sc)

        self.text.set_text(t_str)
        mask=grid.cell_clip_mask(clip,by_center=False)
            
        idxs=np.arange(len(self.scatcolls))
        for ccoll,idx,(ax,scal,label,scat) in zip(self.ccolls,idxs,plots):
            if scal is None: continue
            if valid is not None:
                scal=np.where(valid,scal,np.nan)
            ccoll.set_array(scal[mask])
            if label in self.clims:
                clim=self.clims[label]
            else:
                print(f"{label} not found in clims")
                clim=np.nanmin(scal[mask]),np.nanmax(scal[mask])
            ccoll.set_clim(clim)
            if scat is not None:
                old_scat=self.scatcolls[idx]
                if old_scat is not None:
                    ax.collections.remove(old_scat) # Maybe?
                if len(scat)==0:
                    self.scatcolls[idx]=None
                else:
                    sc=ax.scatter(scat[:,0],scat[:,1],20,scat[:,2],cmap='turbo',zorder=2)
                    sc.set_clim(clim)
                    self.scatcolls[idx] = sc

# %%
lb=LiveBloom(ds)
lb.t=np.datetime64("2022-08-17 12:00")
lb.run()
lb.figure()
# Out:
# Elapsed time for 2391 samples: 0.829s
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

lb=LiveBloom(ds,panels=[['Chl-a','DIN','log10(C0)'],
                        ['mean_depth','effective_age','mean_rad']],figsize=(9,6))
lb.run()
lb.figure()

def run_and_plot(days=0,Nsat=1.00,kmort=0.15,kprod=1.5,
                 N0=35,source_strength=0.1,layer=0,Isat=17.0):
    lb.t=np.datetime64('2022-08-02')+days*np.timedelta64(86400,'s')
    lb.N0=N0
    lb.layer=layer
    lb.source_strength=source_strength
    lb.petri.Kd = Kd
    lb.petri.kmort=kmort
    lb.petri.kprod=kprod
    lb.petri.Isat=Isat
    lb.petri.Nsat=Nsat
    lb.run()
    lb.figure()
    plt.draw()

interact(run_and_plot,
         days=widgets.FloatSlider(value=15,min=0,max=25,continuous_update=False,step=0.1),
         kmort=widgets.FloatSlider(value=0.15,min=0,max=1.0,description="kmort",continuous_update=False,
                                   step=0.01), 
         kprod=widgets.FloatSlider(value=1.5,min=0.1,max=3.0,description="kprod",continuous_update=False,
                                   step=0.01),          
         Nsat=widgets.FloatSlider(value=1.00,min=0,max=10.0,description="Nsat",continuous_update=False,
                                   step=0.05),         
         Isat=widgets.FloatSlider(value=17.0,min=0,max=20,description="Isat",continuous_update=False,
                               step=0.02),
         N0=widgets.FloatSlider(value=35,min=0,max=100,description="N0",continuous_update=False),
         source_strength=widgets.FloatLogSlider(value=0.1,base=10,min=-3,max=3,step=0.1, continuous_update=False),
         layer = widgets.IntSlider(value=0,min=0,max=9)
        )
# Out:
# Elapsed time for 2419 samples: 0.427s
# <img src="data:image/png;base64,..." width="899.9999804930258">
# interactive(children=(FloatSlider(value=15.0, continuous_update=False, description='days', max=25.0), FloatSli…
# <function __main__.run_and_plot(days=0, Nsat=1.0, kmort=0.15, kprod=1.5, N0=35, source_strength=0.1, layer=0, Isat=17.0)>

# %%
# Kd=0.42, kmort=0.15, kprod=2.1, N0=35, source=0.1
# Maybe that's a decent tradeoff

# %%
# Updates:
#  Had been using an age that could be much higher than realistic.
#  With that fixed, and bump Kd up to 0.44 -- 0.48, get a bit more reasonable
#  results.
#  Still, it doesn't quite seem right to use such a small age for the Alameda
#  channel water. Since the seed is just a load, not a water source, chl in
#  that water is not resetting to 0 just because some new seed came in.
#  Is it more appropriate to just set everything to max age? I guess there is 
#  some amount of flushing, so in that sense newly seeded water should have
#  a lower age. part of the problem is also that we're getting an arithmetric mean
#  for age, but it's controlling mixing of exponential growth.
#  Generate a new animation, but need to think about whether it makes sense.

# %%
# animation
frame_dir=os.path.join(run_dir,"frames-Kd0p42-v0")
movie_fn=os.path.join(frame_dir+".mp4")

# %%
lb.ebda_factor=1
lb.lsb_factor=1
lb.N0=35
lb.source_strength=0.1
lb.petri.Kd=0.42
lb.petri.kmort=0.15
lb.petri.kprod=2.1
lb.frac=0.25

if not os.path.exists(frame_dir):
    os.makedirs(frame_dir)
    
for i,t in enumerate(np.arange(np.datetime64("2022-08-02"),
                               np.datetime64("2022-08-22"),
                               np.timedelta64(1800,'s'))):
    img_fn=os.path.join(frame_dir,f"frame_{i:04d}.png")
    lb.t=t
    lb.run()
    lb.figure()
    lb.fig.savefig(img_fn)
# Out:
# Elapsed time for 0 samples: 0.000s
# Elapsed time for 42 samples: 0.002s
# Elapsed time for 71 samples: 0.004s
# Elapsed time for 65 samples: 0.007s
# Elapsed time for 88 samples: 0.009s
# Elapsed time for 82 samples: 0.005s
# Elapsed time for 93 samples: 0.008s
# Elapsed time for 114 samples: 0.012s
# Elapsed time for 105 samples: 0.011s
# Elapsed time for 98 samples: 0.010s
# Elapsed time for 130 samples: 0.009s
# Elapsed time for 146 samples: 0.015s
# Elapsed time for 171 samples: 0.013s
# Elapsed time for 215 samples: 0.019s
# Elapsed time for 255 samples: 0.017s
# Elapsed time for 302 samples: 0.020s
# Elapsed time for 332 samples: 0.028s
# Elapsed time for 350 samples: 0.028s
# Elapsed time for 325 samples: 0.027s
# Elapsed time for 348 samples: 0.026s
# Elapsed time for 369 samples: 0.031s
# Elapsed time for 339 samples: 0.030s
# Elapsed time for 331 samples: 0.028s
# Elapsed time for 379 samples: 0.032s
# Elapsed time for 373 samples: 0.029s
# Elapsed time for 431 samples: 0.037s
# Elapsed time for 391 samples: 0.034s
# Elapsed time for 386 samples: 0.033s
# Elapsed time for 379 samples: 0.035s
# Elapsed time for 393 samples: 0.031s
# Elapsed time for 399 samples: 0.032s
# Elapsed time for 397 samples: 0.037s
# Elapsed time for 436 samples: 0.040s
# Elapsed time for 485 samples: 0.044s
# Elapsed time for 517 samples: 0.041s
# Elapsed time for 616 samples: 0.051s
# Elapsed time for 721 samples: 0.057s
# Elapsed time for 853 samples: 0.068s
# Elapsed time for 921 samples: 0.071s
# Elapsed time for 1071 samples: 0.083s
# Elapsed time for 1190 samples: 0.095s
# Elapsed time for 1288 samples: 0.103s
# Elapsed time for 1331 samples: 0.105s
# Elapsed time for 1440 samples: 0.111s
# Elapsed time for 1393 samples: 0.109s
# Elapsed time for 1553 samples: 0.130s
# Elapsed time for 1587 samples: 0.126s
# Elapsed time for 1563 samples: 0.126s
# Elapsed time for 1526 samples: 0.120s
# Elapsed time for 1542 samples: 0.127s
# Elapsed time for 1521 samples: 0.123s
# Elapsed time for 1493 samples: 0.123s
# Elapsed time for 1457 samples: 0.122s
# Elapsed time for 1515 samples: 0.123s
# Elapsed time for 1497 samples: 0.123s
# Elapsed time for 1555 samples: 0.129s
# Elapsed time for 1655 samples: 0.134s
# Elapsed time for 1653 samples: 0.134s
# Elapsed time for 1673 samples: 0.137s
# Elapsed time for 1630 samples: 0.135s
# Elapsed time for 1794 samples: 0.150s
# Elapsed time for 1853 samples: 0.153s
# Elapsed time for 2041 samples: 0.166s
# Elapsed time for 2080 samples: 0.173s
# Elapsed time for 2172 samples: 0.177s
# Elapsed time for 2363 samples: 0.197s
# Elapsed time for 2590 samples: 0.212s
# Elapsed time for 2650 samples: 0.218s
# Elapsed time for 2834 samples: 0.231s
# Elapsed time for 2878 samples: 0.240s
# Elapsed time for 2876 samples: 0.234s
# Elapsed time for 2857 samples: 0.237s
# Elapsed time for 2952 samples: 0.244s
# Elapsed time for 2831 samples: 0.240s
# Elapsed time for 2900 samples: 0.246s
# Elapsed time for 2751 samples: 0.230s
# Elapsed time for 2834 samples: 0.240s
# Elapsed time for 2828 samples: 0.236s
# Elapsed time for 2809 samples: 0.239s
# Elapsed time for 2766 samples: 0.235s
# Elapsed time for 2726 samples: 0.228s
# Elapsed time for 2696 samples: 0.232s
# Elapsed time for 2674 samples: 0.228s
# Elapsed time for 2754 samples: 0.239s
# Elapsed time for 2704 samples: 0.235s
# Elapsed time for 2814 samples: 0.249s
# Elapsed time for 2960 samples: 0.258s
# Elapsed time for 3127 samples: 0.275s
# Elapsed time for 3612 samples: 0.309s
# Elapsed time for 3707 samples: 0.322s
# Elapsed time for 3804 samples: 0.333s
# Elapsed time for 3995 samples: 0.355s
# Elapsed time for 4249 samples: 0.377s
# Elapsed time for 4360 samples: 0.382s
# Elapsed time for 4445 samples: 0.401s
# Elapsed time for 4403 samples: 0.389s
# Elapsed time for 4413 samples: 0.390s
# Elapsed time for 4379 samples: 0.394s
# Elapsed time for 4371 samples: 0.394s
# Elapsed time for 4342 samples: 0.382s
# Elapsed time for 4189 samples: 0.378s
# Elapsed time for 4366 samples: 0.386s
# Elapsed time for 4294 samples: 0.391s
# Elapsed time for 4314 samples: 0.384s
# Elapsed time for 4308 samples: 0.379s
# Elapsed time for 4296 samples: 0.383s
# Elapsed time for 4306 samples: 0.378s
# Elapsed time for 4201 samples: 0.385s
# Elapsed time for 4345 samples: 0.392s
# Elapsed time for 4167 samples: 0.379s
# Elapsed time for 4279 samples: 0.385s
# Elapsed time for 4256 samples: 0.394s
# Elapsed time for 4424 samples: 0.410s
# Elapsed time for 4669 samples: 0.432s
# Elapsed time for 4817 samples: 0.450s
# Elapsed time for 4788 samples: 0.440s
# Elapsed time for 4984 samples: 0.463s
# Elapsed time for 5001 samples: 0.475s
# Elapsed time for 4994 samples: 0.470s
# Elapsed time for 5275 samples: 0.497s
# Elapsed time for 5256 samples: 0.496s
# Elapsed time for 5182 samples: 0.496s
# Elapsed time for 5252 samples: 0.497s
# Elapsed time for 5275 samples: 0.503s
# Elapsed time for 5297 samples: 0.518s
# Elapsed time for 5205 samples: 0.487s
# Elapsed time for 5200 samples: 0.498s
# Elapsed time for 5249 samples: 0.500s
# Elapsed time for 5033 samples: 0.485s
# Elapsed time for 4979 samples: 0.474s
# Elapsed time for 4989 samples: 0.473s
# Elapsed time for 4971 samples: 0.471s
# Elapsed time for 4836 samples: 0.464s
# Elapsed time for 4826 samples: 0.462s
# Elapsed time for 4977 samples: 0.493s
# Elapsed time for 5076 samples: 0.497s
# Elapsed time for 5205 samples: 0.522s
# Elapsed time for 5307 samples: 0.517s
# Elapsed time for 5501 samples: 0.535s
# Elapsed time for 5642 samples: 0.550s
# Elapsed time for 5656 samples: 0.562s
# Elapsed time for 5859 samples: 0.588s
# Elapsed time for 5971 samples: 0.599s
# Elapsed time for 5860 samples: 0.591s
# Elapsed time for 5930 samples: 0.597s
# Elapsed time for 6186 samples: 0.611s
# Elapsed time for 6113 samples: 0.616s
# Elapsed time for 6055 samples: 0.608s
# Elapsed time for 6069 samples: 0.601s
# Elapsed time for 6069 samples: 0.613s
# Elapsed time for 6080 samples: 0.610s
# Elapsed time for 5947 samples: 0.594s
# Elapsed time for 5968 samples: 0.602s
# Elapsed time for 5827 samples: 0.596s
# Elapsed time for 5799 samples: 0.589s
# Elapsed time for 5708 samples: 0.586s
# Elapsed time for 5798 samples: 0.597s
# Elapsed time for 5586 samples: 0.559s
# Elapsed time for 5659 samples: 0.582s
# Elapsed time for 5740 samples: 0.579s
# Elapsed time for 5637 samples: 0.583s
# Elapsed time for 5655 samples: 0.595s
# Elapsed time for 5654 samples: 0.594s
# Elapsed time for 5895 samples: 0.623s
# Elapsed time for 6029 samples: 0.637s
# Elapsed time for 6123 samples: 0.643s
# Elapsed time for 6330 samples: 0.677s
# Elapsed time for 6248 samples: 0.663s
# Elapsed time for 6414 samples: 0.684s
# Elapsed time for 6478 samples: 0.685s
# Elapsed time for 6513 samples: 0.701s
# Elapsed time for 6648 samples: 0.717s
# Elapsed time for 6574 samples: 0.700s
# Elapsed time for 6418 samples: 0.682s
# Elapsed time for 6351 samples: 0.676s
# Elapsed time for 6502 samples: 0.692s
# Elapsed time for 6483 samples: 0.690s
# Elapsed time for 6420 samples: 0.689s
# Elapsed time for 6351 samples: 0.708s
# Elapsed time for 6259 samples: 0.689s
# Elapsed time for 6348 samples: 0.691s
# Elapsed time for 6197 samples: 0.667s
# Elapsed time for 6416 samples: 0.700s
# Elapsed time for 6391 samples: 0.717s
# Elapsed time for 6286 samples: 0.704s
# Elapsed time for 6475 samples: 0.730s
# Elapsed time for 6469 samples: 0.712s
# Elapsed time for 6686 samples: 0.752s
# Elapsed time for 6857 samples: 0.758s
# Elapsed time for 6995 samples: 0.773s
# Elapsed time for 6942 samples: 0.781s
# Elapsed time for 7052 samples: 0.786s
# Elapsed time for 7029 samples: 0.794s
# Elapsed time for 7218 samples: 0.801s
# Elapsed time for 7245 samples: 0.796s
# Elapsed time for 7136 samples: 0.791s
# Elapsed time for 7189 samples: 0.803s
# Elapsed time for 7129 samples: 0.800s
# Elapsed time for 7058 samples: 0.790s
# Elapsed time for 7077 samples: 0.792s
# Elapsed time for 7016 samples: 0.782s
# Elapsed time for 7113 samples: 0.796s
# Elapsed time for 6977 samples: 0.792s
# Elapsed time for 6976 samples: 0.778s
# Elapsed time for 6867 samples: 0.771s
# Elapsed time for 6910 samples: 0.780s
# Elapsed time for 6733 samples: 0.782s
# Elapsed time for 6805 samples: 0.776s
# Elapsed time for 6705 samples: 0.761s
# Elapsed time for 6697 samples: 0.774s
# Elapsed time for 6780 samples: 0.781s
# Elapsed time for 6704 samples: 0.779s
# Elapsed time for 6729 samples: 0.786s
# Elapsed time for 6852 samples: 0.793s
# Elapsed time for 7041 samples: 0.821s
# Elapsed time for 7116 samples: 0.831s
# Elapsed time for 7344 samples: 0.859s
# Elapsed time for 7436 samples: 0.873s
# Elapsed time for 7418 samples: 0.876s
# Elapsed time for 7566 samples: 0.901s
# Elapsed time for 7529 samples: 0.906s
# Elapsed time for 7567 samples: 0.908s
# Elapsed time for 7502 samples: 0.903s
# Elapsed time for 7434 samples: 0.896s
# Elapsed time for 7465 samples: 0.911s
# Elapsed time for 7448 samples: 0.902s
# Elapsed time for 7505 samples: 0.902s
# Elapsed time for 7402 samples: 0.895s
# Elapsed time for 7376 samples: 0.902s
# Elapsed time for 7487 samples: 0.913s
# Elapsed time for 7492 samples: 0.916s
# Elapsed time for 7453 samples: 0.923s
# Elapsed time for 7515 samples: 0.932s
# Elapsed time for 7626 samples: 0.939s
# Elapsed time for 7303 samples: 0.915s
# Elapsed time for 7526 samples: 0.929s
# Elapsed time for 7516 samples: 0.940s
# Elapsed time for 7751 samples: 0.965s
# Elapsed time for 7782 samples: 0.964s
# Elapsed time for 7751 samples: 0.968s
# Elapsed time for 7930 samples: 0.977s
# Elapsed time for 8103 samples: 1.009s
# Elapsed time for 8137 samples: 1.015s
# Elapsed time for 8295 samples: 1.037s
# Elapsed time for 8138 samples: 1.033s
# Elapsed time for 8164 samples: 1.025s
# Elapsed time for 8241 samples: 1.036s
# Elapsed time for 8299 samples: 1.046s
# Elapsed time for 8166 samples: 1.040s
# Elapsed time for 8198 samples: 1.036s
# Elapsed time for 8321 samples: 1.042s
# Elapsed time for 8186 samples: 1.031s
# Elapsed time for 8151 samples: 1.013s
# Elapsed time for 8218 samples: 1.022s
# Elapsed time for 7984 samples: 0.997s
# Elapsed time for 8057 samples: 0.997s
# Elapsed time for 8015 samples: 1.012s
# Elapsed time for 8246 samples: 1.054s
# Elapsed time for 8021 samples: 1.016s
# Elapsed time for 8002 samples: 1.012s
# Elapsed time for 8090 samples: 1.047s
# Elapsed time for 8026 samples: 1.028s
# Elapsed time for 8095 samples: 1.071s
# Elapsed time for 8387 samples: 1.087s
# Elapsed time for 8477 samples: 1.088s
# Elapsed time for 8528 samples: 1.101s
# Elapsed time for 8654 samples: 1.108s
# Elapsed time for 8741 samples: 1.127s
# Elapsed time for 8950 samples: 1.154s
# Elapsed time for 9104 samples: 1.157s
# Elapsed time for 9158 samples: 1.181s
# Elapsed time for 9281 samples: 1.196s
# Elapsed time for 9349 samples: 1.221s
# Elapsed time for 9469 samples: 1.235s
# Elapsed time for 9438 samples: 1.245s
# Elapsed time for 9483 samples: 1.248s
# Elapsed time for 9419 samples: 1.247s
# Elapsed time for 9283 samples: 1.233s
# Elapsed time for 9262 samples: 1.256s
# Elapsed time for 9430 samples: 1.269s
# Elapsed time for 9267 samples: 1.243s
# Elapsed time for 9171 samples: 1.246s
# Elapsed time for 9264 samples: 1.265s
# Elapsed time for 9234 samples: 1.253s
# Elapsed time for 9222 samples: 1.258s
# Elapsed time for 9178 samples: 1.264s
# Elapsed time for 9226 samples: 1.274s
# Elapsed time for 9350 samples: 1.300s
# Elapsed time for 9451 samples: 1.290s
# Elapsed time for 9417 samples: 1.306s
# Elapsed time for 9531 samples: 1.320s
# Elapsed time for 9795 samples: 1.351s
# Elapsed time for 10054 samples: 1.389s
# Elapsed time for 9905 samples: 1.375s
# Elapsed time for 10034 samples: 1.376s
# Elapsed time for 10073 samples: 1.371s
# Elapsed time for 10399 samples: 1.444s
# Elapsed time for 10276 samples: 1.414s
# Elapsed time for 10364 samples: 1.423s
# Elapsed time for 10409 samples: 1.444s
# Elapsed time for 10318 samples: 1.411s
# Elapsed time for 10201 samples: 1.433s
# Elapsed time for 10114 samples: 1.402s
# Elapsed time for 10070 samples: 1.402s
# Elapsed time for 10043 samples: 1.436s
# Elapsed time for 10090 samples: 1.431s
# Elapsed time for 9913 samples: 1.407s
# Elapsed time for 9995 samples: 1.429s
# Elapsed time for 10016 samples: 1.431s
# Elapsed time for 9936 samples: 1.430s
# Elapsed time for 9908 samples: 1.420s
# Elapsed time for 9987 samples: 1.447s
# Elapsed time for 10032 samples: 1.457s
# Elapsed time for 9869 samples: 1.452s
# Elapsed time for 9933 samples: 1.454s
# Elapsed time for 9752 samples: 1.422s
# Elapsed time for 9961 samples: 1.432s
# Elapsed time for 10252 samples: 1.480s
# Elapsed time for 10077 samples: 1.491s
# Elapsed time for 10229 samples: 1.500s
# Elapsed time for 10121 samples: 1.470s
# Elapsed time for 10400 samples: 1.515s
# Elapsed time for 10518 samples: 1.537s
# Elapsed time for 10284 samples: 1.506s
# Elapsed time for 10533 samples: 1.555s
# Elapsed time for 10351 samples: 1.532s
# Elapsed time for 10636 samples: 1.560s
# Elapsed time for 10498 samples: 1.549s
# Elapsed time for 10511 samples: 1.553s
# Elapsed time for 10370 samples: 1.531s
# Elapsed time for 10438 samples: 1.554s
# Elapsed time for 10310 samples: 1.527s
# Elapsed time for 10531 samples: 1.562s
# Elapsed time for 10449 samples: 1.533s
# Elapsed time for 10498 samples: 1.578s
# Elapsed time for 10315 samples: 1.534s
# Elapsed time for 10270 samples: 1.549s
# Elapsed time for 10429 samples: 1.570s
# Elapsed time for 10381 samples: 1.590s
# Elapsed time for 10320 samples: 1.561s
# Elapsed time for 10626 samples: 1.610s
# Elapsed time for 10457 samples: 1.576s
# Elapsed time for 10755 samples: 1.638s
# Elapsed time for 10635 samples: 1.626s
# Elapsed time for 10936 samples: 1.663s
# Elapsed time for 10962 samples: 1.654s
# Elapsed time for 10779 samples: 1.651s
# Elapsed time for 10895 samples: 1.640s
# Elapsed time for 11024 samples: 1.682s
# Elapsed time for 10964 samples: 1.657s
# Elapsed time for 11009 samples: 1.677s
# Elapsed time for 10898 samples: 1.674s
# Elapsed time for 11113 samples: 1.685s
# Elapsed time for 10905 samples: 1.671s
# Elapsed time for 11089 samples: 1.718s
# Elapsed time for 11161 samples: 1.725s
# Elapsed time for 10916 samples: 1.694s
# Elapsed time for 10981 samples: 1.716s
# Elapsed time for 10961 samples: 1.729s
# Elapsed time for 11018 samples: 1.753s
# Elapsed time for 11160 samples: 1.791s
# Elapsed time for 10908 samples: 1.737s
# Elapsed time for 10754 samples: 1.711s
# Elapsed time for 11064 samples: 1.768s
# Elapsed time for 10883 samples: 1.725s
# Elapsed time for 10952 samples: 1.746s
# Elapsed time for 10969 samples: 1.725s
# Elapsed time for 10931 samples: 1.706s
# Elapsed time for 11054 samples: 1.760s
# Elapsed time for 11096 samples: 1.747s
# Elapsed time for 11079 samples: 1.749s
# Elapsed time for 11096 samples: 1.761s
# Elapsed time for 10994 samples: 1.731s
# Elapsed time for 11020 samples: 1.753s
# Elapsed time for 11334 samples: 1.828s
# Elapsed time for 11175 samples: 1.777s
# Elapsed time for 11333 samples: 1.794s
# Elapsed time for 11352 samples: 1.794s
# Elapsed time for 11077 samples: 1.771s
# Elapsed time for 11109 samples: 1.779s
# Elapsed time for 11186 samples: 1.793s
# Elapsed time for 11111 samples: 1.778s
# Elapsed time for 11234 samples: 1.822s
# Elapsed time for 11264 samples: 1.829s
# Elapsed time for 11137 samples: 1.800s
# Elapsed time for 11158 samples: 1.820s
# Elapsed time for 11208 samples: 1.823s
# Elapsed time for 11263 samples: 1.833s
# Elapsed time for 11299 samples: 1.874s
# Elapsed time for 11353 samples: 1.860s
# Elapsed time for 11158 samples: 1.827s
# Elapsed time for 11038 samples: 1.802s
# Elapsed time for 11165 samples: 1.817s
# Elapsed time for 11079 samples: 1.805s
# Elapsed time for 11492 samples: 1.878s
# Elapsed time for 11406 samples: 1.875s
# Elapsed time for 11383 samples: 1.871s
# Elapsed time for 11590 samples: 1.909s
# Elapsed time for 11373 samples: 1.875s
# Elapsed time for 11557 samples: 1.904s
# Elapsed time for 11451 samples: 1.898s
# Elapsed time for 11440 samples: 1.937s
# Elapsed time for 11591 samples: 1.983s
# Elapsed time for 11505 samples: 1.948s
# Elapsed time for 11634 samples: 1.988s
# Elapsed time for 11649 samples: 2.006s
# Elapsed time for 11473 samples: 1.978s
# Elapsed time for 11604 samples: 2.018s
# Elapsed time for 11482 samples: 2.008s
# Elapsed time for 11738 samples: 2.076s
# Elapsed time for 11526 samples: 2.028s
# Elapsed time for 11699 samples: 2.064s
# Elapsed time for 11618 samples: 2.068s
# Elapsed time for 11561 samples: 2.033s
# Elapsed time for 11485 samples: 2.009s
# Elapsed time for 11696 samples: 2.040s
# Elapsed time for 11448 samples: 1.993s
# Elapsed time for 11524 samples: 1.977s
# Elapsed time for 11636 samples: 1.974s
# Elapsed time for 11660 samples: 1.996s
# Elapsed time for 11631 samples: 1.985s
# Elapsed time for 11525 samples: 1.963s
# Elapsed time for 11584 samples: 1.987s
# Elapsed time for 11526 samples: 1.990s
# Elapsed time for 11830 samples: 2.059s
# Elapsed time for 11512 samples: 1.999s
# Elapsed time for 11660 samples: 2.049s
# Elapsed time for 11706 samples: 2.050s
# Elapsed time for 11784 samples: 2.065s
# Elapsed time for 11570 samples: 2.034s
# Elapsed time for 11649 samples: 2.103s
# Elapsed time for 11719 samples: 2.101s
# Elapsed time for 11821 samples: 2.129s
# Elapsed time for 11732 samples: 2.120s
# Elapsed time for 11717 samples: 2.089s
# Elapsed time for 11731 samples: 2.115s
# Elapsed time for 11696 samples: 2.128s
# Elapsed time for 11764 samples: 2.140s
# Elapsed time for 11733 samples: 2.132s
# Elapsed time for 11695 samples: 2.093s
# Elapsed time for 11684 samples: 2.082s
# Elapsed time for 11631 samples: 2.100s
# Elapsed time for 11639 samples: 2.068s
# Elapsed time for 11693 samples: 2.107s
# Elapsed time for 11727 samples: 2.147s
# Elapsed time for 11724 samples: 2.129s
# Elapsed time for 11741 samples: 2.151s
# Elapsed time for 11706 samples: 2.137s
# Elapsed time for 11658 samples: 2.158s
# Elapsed time for 11753 samples: 2.182s
# Elapsed time for 11840 samples: 2.213s
# Elapsed time for 11865 samples: 2.240s
# Elapsed time for 11810 samples: 2.237s
# Elapsed time for 11846 samples: 2.304s
# Elapsed time for 11954 samples: 2.341s
# Elapsed time for 11775 samples: 2.306s
# Elapsed time for 11852 samples: 2.342s
# Elapsed time for 11938 samples: 2.376s
# Elapsed time for 11813 samples: 2.422s
# Elapsed time for 12004 samples: 2.439s
# Elapsed time for 11912 samples: 2.449s
# Elapsed time for 11634 samples: 2.373s
# Elapsed time for 11830 samples: 2.399s
# Elapsed time for 11677 samples: 2.367s
# Elapsed time for 11607 samples: 2.311s
# Elapsed time for 11869 samples: 2.304s
# Elapsed time for 11732 samples: 2.283s
# Elapsed time for 11730 samples: 2.251s
# Elapsed time for 11874 samples: 2.294s
# Elapsed time for 11756 samples: 2.242s
# Elapsed time for 11826 samples: 2.253s
# Elapsed time for 11728 samples: 2.233s
# Elapsed time for 11796 samples: 2.277s
# Elapsed time for 11875 samples: 2.277s
# Elapsed time for 11955 samples: 2.274s
# Elapsed time for 11770 samples: 2.261s
# Elapsed time for 11846 samples: 2.311s
# Elapsed time for 11842 samples: 2.327s
# Elapsed time for 11768 samples: 2.336s
# Elapsed time for 11822 samples: 2.343s
# Elapsed time for 12018 samples: 2.438s
# Elapsed time for 12094 samples: 2.454s
# Elapsed time for 11922 samples: 2.467s
# Elapsed time for 11723 samples: 2.404s
# Elapsed time for 11650 samples: 2.436s
# Elapsed time for 11850 samples: 2.472s
# Elapsed time for 11875 samples: 2.500s
# Elapsed time for 11912 samples: 2.462s
# Elapsed time for 11875 samples: 2.443s
# Elapsed time for 11854 samples: 2.382s
# Elapsed time for 11686 samples: 2.349s
# Elapsed time for 11933 samples: 2.374s
# Elapsed time for 11667 samples: 2.341s
# Elapsed time for 11867 samples: 2.363s
# Elapsed time for 11836 samples: 2.350s
# Elapsed time for 11940 samples: 2.349s
# Elapsed time for 11875 samples: 2.380s
# Elapsed time for 11772 samples: 2.402s
# Elapsed time for 11957 samples: 2.439s
# Elapsed time for 12017 samples: 2.477s
# Elapsed time for 11993 samples: 2.537s
# Elapsed time for 11985 samples: 2.535s
# Elapsed time for 11975 samples: 2.560s
# Elapsed time for 11908 samples: 2.576s
# Elapsed time for 11867 samples: 2.608s
# Elapsed time for 12038 samples: 2.698s
# Elapsed time for 11916 samples: 2.706s
# Elapsed time for 11872 samples: 2.741s
# Elapsed time for 11917 samples: 2.817s
# Elapsed time for 11984 samples: 2.835s
# Elapsed time for 12081 samples: 2.872s
# Elapsed time for 11929 samples: 2.849s
# Elapsed time for 11855 samples: 2.804s
# Elapsed time for 11990 samples: 2.798s
# Elapsed time for 11940 samples: 2.737s
# Elapsed time for 11858 samples: 2.659s
# Elapsed time for 11908 samples: 2.600s
# Elapsed time for 11893 samples: 2.616s
# Elapsed time for 11854 samples: 2.539s
# Elapsed time for 11849 samples: 2.534s
# Elapsed time for 12134 samples: 2.595s
# Elapsed time for 12003 samples: 2.539s
# Elapsed time for 11851 samples: 2.522s
# Elapsed time for 12069 samples: 2.561s
# Elapsed time for 11951 samples: 2.569s
# Elapsed time for 11824 samples: 2.554s
# Elapsed time for 11897 samples: 2.611s
# Elapsed time for 12040 samples: 2.650s
# Elapsed time for 11940 samples: 2.716s
# Elapsed time for 11817 samples: 2.670s
# Elapsed time for 12072 samples: 2.781s
# Elapsed time for 11923 samples: 2.746s
# Elapsed time for 12114 samples: 2.858s
# Elapsed time for 12042 samples: 2.861s
# Elapsed time for 11870 samples: 2.812s
# Elapsed time for 11933 samples: 2.834s
# Elapsed time for 11984 samples: 2.823s
# Elapsed time for 12024 samples: 2.819s
# Elapsed time for 11822 samples: 2.758s
# Elapsed time for 11873 samples: 2.727s
# Elapsed time for 11891 samples: 2.717s
# Elapsed time for 11952 samples: 2.715s
# Elapsed time for 12094 samples: 2.729s
# Elapsed time for 11793 samples: 2.660s
# Elapsed time for 11879 samples: 2.644s
# Elapsed time for 11917 samples: 2.693s
# Elapsed time for 11778 samples: 2.665s
# Elapsed time for 12031 samples: 2.732s
# Elapsed time for 11916 samples: 2.751s
# Elapsed time for 11904 samples: 2.790s
# Elapsed time for 12073 samples: 2.843s
# Elapsed time for 11925 samples: 2.864s
# Elapsed time for 12093 samples: 2.956s
# Elapsed time for 11919 samples: 2.998s
# Elapsed time for 11906 samples: 3.051s
# Elapsed time for 12062 samples: 3.191s
# Elapsed time for 12040 samples: 3.224s
# Elapsed time for 11953 samples: 3.255s
# Elapsed time for 11886 samples: 3.286s
# Elapsed time for 12134 samples: 3.374s
# Elapsed time for 12086 samples: 3.360s
# Elapsed time for 12017 samples: 3.323s
# Elapsed time for 12152 samples: 3.270s
# Elapsed time for 11896 samples: 3.173s
# Elapsed time for 12072 samples: 3.128s
# Elapsed time for 11951 samples: 3.028s
# Elapsed time for 12002 samples: 2.997s
# Elapsed time for 11953 samples: 2.960s
# Elapsed time for 11877 samples: 2.887s
# Elapsed time for 12064 samples: 2.934s
# Elapsed time for 12013 samples: 2.950s
# Elapsed time for 12061 samples: 2.921s
# Elapsed time for 11921 samples: 2.918s
# Elapsed time for 12071 samples: 2.955s
# Elapsed time for 11880 samples: 2.936s
# Elapsed time for 11982 samples: 3.022s
# Elapsed time for 12066 samples: 3.083s
# Elapsed time for 12139 samples: 3.114s
# Elapsed time for 12112 samples: 3.163s
# Elapsed time for 12066 samples: 3.212s
# Elapsed time for 12015 samples: 3.230s
# Elapsed time for 12037 samples: 3.363s
# Elapsed time for 12110 samples: 3.431s
# Elapsed time for 11951 samples: 3.362s
# Elapsed time for 11935 samples: 3.460s
# Elapsed time for 12075 samples: 3.482s
# Elapsed time for 12038 samples: 3.411s
# Elapsed time for 12197 samples: 3.402s
# Elapsed time for 11947 samples: 3.306s
# Elapsed time for 11956 samples: 3.324s
# Elapsed time for 11743 samples: 3.200s
# Elapsed time for 12062 samples: 3.237s
# Elapsed time for 12121 samples: 3.230s
# Elapsed time for 11891 samples: 3.127s
# Elapsed time for 11952 samples: 3.155s
# Elapsed time for 12079 samples: 3.241s
# Elapsed time for 11937 samples: 3.207s
# Elapsed time for 12118 samples: 3.301s
# Elapsed time for 12037 samples: 3.401s
# Elapsed time for 12079 samples: 3.439s
# Elapsed time for 12194 samples: 3.536s
# Elapsed time for 12005 samples: 3.551s
# Elapsed time for 12021 samples: 3.661s
# Elapsed time for 12174 samples: 3.806s
# Elapsed time for 12121 samples: 3.869s
# Elapsed time for 12152 samples: 3.989s
# Elapsed time for 12042 samples: 4.069s
# Elapsed time for 12032 samples: 4.142s
# Elapsed time for 12126 samples: 4.259s
# Elapsed time for 12020 samples: 4.255s
# Elapsed time for 11960 samples: 4.320s
# Elapsed time for 12079 samples: 4.363s
# Elapsed time for 11946 samples: 4.265s
# Elapsed time for 12052 samples: 4.215s
# Elapsed time for 12125 samples: 4.117s
# Elapsed time for 11971 samples: 3.976s
# Elapsed time for 12089 samples: 3.955s
# Elapsed time for 12031 samples: 3.827s
# Elapsed time for 11990 samples: 3.712s
# Elapsed time for 12001 samples: 3.738s
# Elapsed time for 12027 samples: 3.738s
# Elapsed time for 11925 samples: 3.765s
# Elapsed time for 12072 samples: 3.841s
# Elapsed time for 12048 samples: 3.865s
# Elapsed time for 12079 samples: 4.035s
# Elapsed time for 12012 samples: 4.134s
# Elapsed time for 12221 samples: 4.322s
# Elapsed time for 12091 samples: 4.385s
# Elapsed time for 12227 samples: 4.601s
# Elapsed time for 12164 samples: 4.599s
# Elapsed time for 11959 samples: 4.593s
# Elapsed time for 12083 samples: 4.717s
# Elapsed time for 12065 samples: 4.796s
# Elapsed time for 12027 samples: 4.772s
# Elapsed time for 12032 samples: 4.806s
# Elapsed time for 12103 samples: 4.804s
# Elapsed time for 12265 samples: 4.860s
# Elapsed time for 12111 samples: 4.766s
# Elapsed time for 12029 samples: 4.629s
# Elapsed time for 12121 samples: 4.536s
# Elapsed time for 11863 samples: 4.513s
# Elapsed time for 11978 samples: 4.460s
# Elapsed time for 11966 samples: 4.377s
# Elapsed time for 12215 samples: 4.476s
# Elapsed time for 12081 samples: 4.449s
# Elapsed time for 11907 samples: 4.413s
# Elapsed time for 11983 samples: 4.553s
# Elapsed time for 12019 samples: 4.601s
# Elapsed time for 12110 samples: 4.747s
# Elapsed time for 12104 samples: 4.832s
# Elapsed time for 12101 samples: 4.870s
# Elapsed time for 12008 samples: 4.965s
# Elapsed time for 12106 samples: 5.033s
# Elapsed time for 12079 samples: 5.037s
# Elapsed time for 11996 samples: 5.200s
# Elapsed time for 12131 samples: 5.196s
# Elapsed time for 12091 samples: 5.235s
# Elapsed time for 11958 samples: 5.165s
# Elapsed time for 12054 samples: 5.186s
# Elapsed time for 12076 samples: 5.181s
# Elapsed time for 12087 samples: 5.186s
# Elapsed time for 12042 samples: 5.176s
# Elapsed time for 12151 samples: 5.158s
# Elapsed time for 12045 samples: 5.046s
# Elapsed time for 12176 samples: 4.969s
# Elapsed time for 12071 samples: 4.883s
# Elapsed time for 11977 samples: 4.800s
# Elapsed time for 12015 samples: 4.762s
# Elapsed time for 11958 samples: 4.807s
# Elapsed time for 12135 samples: 4.822s
# Elapsed time for 11901 samples: 4.695s
# Elapsed time for 12207 samples: 4.878s
# Elapsed time for 12095 samples: 4.898s
# Elapsed time for 12066 samples: 4.928s
# Elapsed time for 12099 samples: 4.981s
# Elapsed time for 11996 samples: 4.997s
# Elapsed time for 12096 samples: 5.051s
# Elapsed time for 12319 samples: 5.219s
# Elapsed time for 12106 samples: 5.171s
# Elapsed time for 12081 samples: 5.179s
# Elapsed time for 12256 samples: 5.279s
# Elapsed time for 11929 samples: 5.205s
# Elapsed time for 12159 samples: 5.403s
# Elapsed time for 12112 samples: 5.308s
# Elapsed time for 12203 samples: 5.294s
# Elapsed time for 12058 samples: 5.241s
# Elapsed time for 12306 samples: 5.342s
# Elapsed time for 11908 samples: 5.104s
# Elapsed time for 12085 samples: 5.097s
# Elapsed time for 12070 samples: 5.121s
# Elapsed time for 12078 samples: 5.112s
# Elapsed time for 11966 samples: 5.049s
# Elapsed time for 12055 samples: 5.072s
# Elapsed time for 12151 samples: 5.125s
# Elapsed time for 11944 samples: 4.994s
# Elapsed time for 11995 samples: 5.063s
# Elapsed time for 11918 samples: 5.144s
# Elapsed time for 12289 samples: 5.326s
# Elapsed time for 12117 samples: 5.264s
# Elapsed time for 12057 samples: 5.278s
# Elapsed time for 12066 samples: 5.289s
# Elapsed time for 12062 samples: 5.413s
# Elapsed time for 12104 samples: 5.417s
# Elapsed time for 11982 samples: 5.407s
# Elapsed time for 12110 samples: 5.489s
# Elapsed time for 12122 samples: 5.541s
# Elapsed time for 12134 samples: 5.471s
# Elapsed time for 12172 samples: 5.567s
# Elapsed time for 12136 samples: 5.564s
# Elapsed time for 11996 samples: 5.427s
# Elapsed time for 12136 samples: 5.501s
# Elapsed time for 12256 samples: 5.475s
# Elapsed time for 12249 samples: 5.435s
# Elapsed time for 12146 samples: 5.309s
# Elapsed time for 12048 samples: 5.174s
# Elapsed time for 12002 samples: 5.202s
# Elapsed time for 11950 samples: 5.128s
# Elapsed time for 12042 samples: 5.124s
# Elapsed time for 12096 samples: 5.120s
# Elapsed time for 12177 samples: 5.184s
# Elapsed time for 12117 samples: 5.215s
# Elapsed time for 12227 samples: 5.303s
# Elapsed time for 12143 samples: 5.235s
# Elapsed time for 12048 samples: 5.206s
# Elapsed time for 12042 samples: 5.408s
# Elapsed time for 12139 samples: 5.350s
# Elapsed time for 12227 samples: 5.490s
# Elapsed time for 12128 samples: 5.448s
# Elapsed time for 12221 samples: 5.527s
# Elapsed time for 12347 samples: 5.640s
# Elapsed time for 12384 samples: 5.672s
# Elapsed time for 12095 samples: 5.515s
# Elapsed time for 12170 samples: 5.622s
# Elapsed time for 12096 samples: 5.579s
# Elapsed time for 12220 samples: 5.665s
# Elapsed time for 12154 samples: 5.552s
# Elapsed time for 12559 samples: 5.748s
# Elapsed time for 12016 samples: 5.489s
# Elapsed time for 12104 samples: 5.576s
# Elapsed time for 12329 samples: 5.526s
# Elapsed time for 12226 samples: 5.514s
# Elapsed time for 12147 samples: 5.468s
# Elapsed time for 11972 samples: 5.374s
# Elapsed time for 12159 samples: 5.340s
# Elapsed time for 11991 samples: 5.347s
# Elapsed time for 12107 samples: 5.461s
# Elapsed time for 12036 samples: 5.422s
# Elapsed time for 12131 samples: 5.486s
# Elapsed time for 12053 samples: 5.458s
# Elapsed time for 12146 samples: 5.609s
# Elapsed time for 12062 samples: 5.538s
# Elapsed time for 12004 samples: 5.529s
# Elapsed time for 12126 samples: 5.762s
# Elapsed time for 12181 samples: 5.713s
# Elapsed time for 12235 samples: 5.738s
# Elapsed time for 12132 samples: 5.718s
# Elapsed time for 12260 samples: 5.796s
# Elapsed time for 12254 samples: 5.774s
# Elapsed time for 12155 samples: 5.673s
# Elapsed time for 12071 samples: 5.682s
# Elapsed time for 12196 samples: 5.653s
# Elapsed time for 12283 samples: 5.676s
# Elapsed time for 11843 samples: 5.442s
# Elapsed time for 12007 samples: 5.500s
# Elapsed time for 12070 samples: 5.450s
# Elapsed time for 12272 samples: 5.545s
# Elapsed time for 11903 samples: 5.348s
# Elapsed time for 12060 samples: 5.444s
# Elapsed time for 11938 samples: 5.348s
# Elapsed time for 12173 samples: 5.482s
# Elapsed time for 12133 samples: 5.528s
# Elapsed time for 11979 samples: 5.411s
# Elapsed time for 12088 samples: 5.461s
# Elapsed time for 12150 samples: 5.542s
# Elapsed time for 12142 samples: 5.605s
# Elapsed time for 12072 samples: 5.577s
# Elapsed time for 12060 samples: 5.658s
# Elapsed time for 12131 samples: 5.694s
# Elapsed time for 12121 samples: 5.744s
# Elapsed time for 12185 samples: 5.808s
# Elapsed time for 12203 samples: 5.893s
# Elapsed time for 12126 samples: 5.821s
# Elapsed time for 12227 samples: 5.884s
# Elapsed time for 12070 samples: 5.906s
# Elapsed time for 12255 samples: 5.901s
# Elapsed time for 12209 samples: 5.853s
# Elapsed time for 11976 samples: 5.671s
# Elapsed time for 12142 samples: 5.787s
# Elapsed time for 12223 samples: 5.805s
# Elapsed time for 12081 samples: 5.733s
# Elapsed time for 11974 samples: 5.648s
# Elapsed time for 12169 samples: 5.776s
# Elapsed time for 11927 samples: 5.546s
# Elapsed time for 12096 samples: 5.680s
# Elapsed time for 11985 samples: 5.634s
# Elapsed time for 12036 samples: 5.674s
# Elapsed time for 11894 samples: 5.582s
# Elapsed time for 12146 samples: 5.809s
# Elapsed time for 12027 samples: 5.743s
# Elapsed time for 12031 samples: 5.785s
# Elapsed time for 12204 samples: 5.874s
# Elapsed time for 12180 samples: 5.915s
# Elapsed time for 12079 samples: 5.911s
# Elapsed time for 12071 samples: 5.862s
# Elapsed time for 12110 samples: 5.927s
# Elapsed time for 12106 samples: 5.912s
# Elapsed time for 12207 samples: 5.994s
# Elapsed time for 12121 samples: 5.968s
# Elapsed time for 12316 samples: 6.117s
# Elapsed time for 12178 samples: 5.982s
# Elapsed time for 12138 samples: 5.876s
# Elapsed time for 12009 samples: 5.747s
# Elapsed time for 11898 samples: 5.672s
# Elapsed time for 12077 samples: 5.707s
# Elapsed time for 12015 samples: 5.659s
# Elapsed time for 11926 samples: 5.651s
# Elapsed time for 12191 samples: 5.723s
# Elapsed time for 12004 samples: 5.650s
# Elapsed time for 12154 samples: 5.712s
# Elapsed time for 11936 samples: 5.630s
# Elapsed time for 11972 samples: 5.671s
# Elapsed time for 12153 samples: 5.828s
# Elapsed time for 11969 samples: 5.736s
# Elapsed time for 11953 samples: 5.735s
# Elapsed time for 11975 samples: 5.763s
# Elapsed time for 12146 samples: 5.880s
# Elapsed time for 12132 samples: 5.978s
# Elapsed time for 12103 samples: 5.936s
# Elapsed time for 12119 samples: 5.949s
# Elapsed time for 12078 samples: 5.991s
# Elapsed time for 12199 samples: 6.096s
# Elapsed time for 12047 samples: 6.016s
# Elapsed time for 12187 samples: 6.099s
# Elapsed time for 12191 samples: 6.131s
# Elapsed time for 12165 samples: 6.080s
# Elapsed time for 11837 samples: 5.880s
# Elapsed time for 12095 samples: 6.038s
# Elapsed time for 11883 samples: 5.872s
# Elapsed time for 11921 samples: 5.889s
# Elapsed time for 12144 samples: 5.980s
# Elapsed time for 11989 samples: 5.869s
# Elapsed time for 12043 samples: 5.929s
# Elapsed time for 12223 samples: 6.000s
# Elapsed time for 12092 samples: 5.893s
# Elapsed time for 12118 samples: 5.986s
# Elapsed time for 12095 samples: 5.911s
# Elapsed time for 12159 samples: 5.907s
# Elapsed time for 11951 samples: 5.902s
# Elapsed time for 11858 samples: 5.920s
# Elapsed time for 11950 samples: 5.886s
# Elapsed time for 12021 samples: 6.022s
# Elapsed time for 11979 samples: 6.014s
# Elapsed time for 12086 samples: 6.032s
# Elapsed time for 12177 samples: 6.142s
# Elapsed time for 11947 samples: 6.041s
# Elapsed time for 12057 samples: 6.049s
# Elapsed time for 12110 samples: 6.068s
# Elapsed time for 12132 samples: 6.094s
# Elapsed time for 12195 samples: 6.107s
# Elapsed time for 12112 samples: 6.101s
# Elapsed time for 12040 samples: 6.055s
# Elapsed time for 11970 samples: 5.908s
# Elapsed time for 11971 samples: 5.957s
# Elapsed time for 11905 samples: 5.825s
# Elapsed time for 12037 samples: 5.931s
# Elapsed time for 11755 samples: 5.743s
# Elapsed time for 12064 samples: 5.878s
# Elapsed time for 11917 samples: 5.796s
# Elapsed time for 11932 samples: 5.781s
# Elapsed time for 11777 samples: 5.759s
# Elapsed time for 12048 samples: 5.907s
# Elapsed time for 12132 samples: 5.981s
# Elapsed time for 12095 samples: 5.935s
# Elapsed time for 11862 samples: 5.827s
# Elapsed time for 12052 samples: 6.013s
# Elapsed time for 12084 samples: 6.040s
# Elapsed time for 12229 samples: 6.135s
# Elapsed time for 12095 samples: 6.094s
# Elapsed time for 12092 samples: 6.212s
# Elapsed time for 12185 samples: 6.194s
# Elapsed time for 12215 samples: 6.228s
# Elapsed time for 12090 samples: 6.221s
# Elapsed time for 12187 samples: 6.207s
# Elapsed time for 12104 samples: 6.247s
# Elapsed time for 12192 samples: 6.249s
# Elapsed time for 12243 samples: 6.327s
# Elapsed time for 12178 samples: 6.200s
# Elapsed time for 12071 samples: 6.120s
# Elapsed time for 12156 samples: 6.129s
# Elapsed time for 12222 samples: 6.117s
# Elapsed time for 12026 samples: 6.061s
# Elapsed time for 12297 samples: 6.201s
# Elapsed time for 12047 samples: 6.055s
# Elapsed time for 12030 samples: 6.048s
# Elapsed time for 12036 samples: 6.016s
# Elapsed time for 12110 samples: 6.045s
# Elapsed time for 11887 samples: 5.899s
# Elapsed time for 11883 samples: 5.958s
# Elapsed time for 12003 samples: 6.041s
# Elapsed time for 12053 samples: 6.077s
# Elapsed time for 12119 samples: 6.101s
# Elapsed time for 12091 samples: 6.105s
# Elapsed time for 12215 samples: 6.184s
# Elapsed time for 11988 samples: 6.118s
# Elapsed time for 12049 samples: 6.084s
# Elapsed time for 11993 samples: 6.115s
# Elapsed time for 11990 samples: 6.169s
# Elapsed time for 11989 samples: 6.127s
# Elapsed time for 12143 samples: 6.182s
# Elapsed time for 12150 samples: 6.187s
# Elapsed time for 11968 samples: 6.080s
# Elapsed time for 12069 samples: 6.037s
# Elapsed time for 12178 samples: 6.123s
# Elapsed time for 12108 samples: 6.026s
# Elapsed time for 12066 samples: 6.053s
# Elapsed time for 11923 samples: 6.002s
# Elapsed time for 12245 samples: 6.037s
# Elapsed time for 12025 samples: 5.974s
# Elapsed time for 12184 samples: 6.051s
# Elapsed time for 12026 samples: 5.988s
# Elapsed time for 12333 samples: 6.207s
# Elapsed time for 12009 samples: 5.950s
# Elapsed time for 12022 samples: 6.044s
# Elapsed time for 12035 samples: 6.092s
# Elapsed time for 12188 samples: 6.187s
# Elapsed time for 11951 samples: 6.122s
# Elapsed time for 12255 samples: 6.286s
# Elapsed time for 12288 samples: 6.364s
# Elapsed time for 12039 samples: 6.199s
# Elapsed time for 12282 samples: 6.346s
# Elapsed time for 12193 samples: 6.343s
# Elapsed time for 12226 samples: 6.430s
# Elapsed time for 12276 samples: 6.436s
# Elapsed time for 12039 samples: 6.286s
# Elapsed time for 12300 samples: 6.464s
# Elapsed time for 12182 samples: 6.361s
# Elapsed time for 12026 samples: 6.284s
# Elapsed time for 12315 samples: 6.364s
# Elapsed time for 12099 samples: 6.204s
# Elapsed time for 12360 samples: 6.374s
# Elapsed time for 12158 samples: 6.258s
# Elapsed time for 12154 samples: 6.188s
# Elapsed time for 12163 samples: 6.165s
# Elapsed time for 12117 samples: 6.114s
# Elapsed time for 12063 samples: 6.083s
# Elapsed time for 11950 samples: 6.049s
# Elapsed time for 11967 samples: 6.008s
# Elapsed time for 12093 samples: 6.114s
# Elapsed time for 12067 samples: 6.126s
# Elapsed time for 12192 samples: 6.178s
# Elapsed time for 12049 samples: 6.126s
# Elapsed time for 11952 samples: 6.071s
# Elapsed time for 12019 samples: 6.119s
# Elapsed time for 12044 samples: 6.161s
# Elapsed time for 12160 samples: 6.233s
# Elapsed time for 12197 samples: 6.274s
# Elapsed time for 12110 samples: 6.248s
# Elapsed time for 12029 samples: 6.218s
# Elapsed time for 12106 samples: 6.288s
# Elapsed time for 12145 samples: 6.232s

# %%
# Compile to animation


if os.path.exists(movie_fn):
    os.unlink(movie_fn)
subprocess.run(f"ffmpeg -framerate 16 -i {os.path.join(frame_dir,'frame_%04d.png')} "
                "-c:v libx264 -preset slow -profile:v high -level:v 4.0 "
               f"-pix_fmt yuv420p -crf 20 -r 16 {movie_fn}",
               shell=True)

# %%
Video(movie_fn) # chl limit to 120, DIN to 35, log10(c0) -5,2
# mean _depth to 10, effective age to 20
# but it's not really pushing into the channel as much as I'd like.
# Out:
# <video src="run_wy2022_bloom_common_20220802/frames-Kd0p42-v0.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
